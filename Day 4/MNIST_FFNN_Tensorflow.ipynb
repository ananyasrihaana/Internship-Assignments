# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = (tf.keras.datasets.mnist.load_data())

train_images = train_images.astype("float32") / 255.0
test_images = test_images.astype("float32") / 255.0

train_images = train_images.reshape((60000, 28 * 28))
test_images = test_images.reshape((10000, 28 * 28))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = models.Sequential([
    layers.Dense(1024, activation='swish', kernel_regularizer=regularizers.l2(1e-4), input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(256, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(10, activation='softmax')
])

# %%
plt.figure(figsize=(10, 5))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.imshow(train_images[i].reshape(28, 28), cmap="gray")
    plt.title(f"Label: {train_labels[i]}")
    plt.axis("off")
plt.suptitle("Sample MNIST Images with Labels", y=1.02)
plt.tight_layout()
plt.show()

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 1024)           │       803,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,469,706 (5.61 MB)
#  Trainable params: 1,466,122 (5.59 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-5, verbose=1)

# %%
train_labels_cat = to_categorical(train_labels, num_classes=10)

history = model.fit(
    train_images, train_labels_cat,
    epochs=30,
    batch_size=128,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.8799 - loss: 0.5685 - val_accuracy: 0.9662 - val_loss: 0.2746 - learning_rate: 0.0010
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 39s 51ms/step - accuracy: 0.9617 - loss: 0.2841 - val_accuracy: 0.9773 - val_loss: 0.2352 - learning_rate: 0.0010
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9685 - loss: 0.2515 - val_accuracy: 0.9778 - val_loss: 0.2250 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9739 - loss: 0.2264 - val_accuracy: 0.9807 - val_loss: 0.2049 - learning_rate: 0.0010
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.9760 - loss: 0.2120 - val_accuracy: 0.9825 - val_loss: 0.1991 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9782 - loss: 0.2007 - val_accuracy: 0.9827 - val_loss: 0.1974 - learning_rate: 0.0010
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.9784 - loss: 0.1995 - val_accuracy: 0.9830 - val_loss: 0.1951 - learning_rate: 0.0010
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 48ms/step - accuracy: 0.9802 - loss: 0.1883 - val_accuracy: 0.9810 - val_loss: 0.1915 - learning_rate: 0.0010
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9808 - loss: 0.1861 - val_accuracy: 0.9815 - val_loss: 0.1900 - learning_rate: 0.0010
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9801 - loss: 0.1839 - val_accuracy: 0.9787 - val_loss: 0.2048 - learning_rate: 0.0010
# Epoch 11/30
# 421/422 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9807 - loss: 0.1843
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9807 - loss: 0.1843 - val_accuracy: 0.9812 - val_loss: 0.1924 - learning_rate: 0.0010
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9865 - loss: 0.1642 - val_accuracy: 0.9863 - val_loss: 0.1578 - learning_rate: 5.0000e-04
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9914 - loss: 0.1380 - val_accuracy: 0.9872 - val_loss: 0.1532 - learning_rate: 5.0000e-04
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9900 - loss: 0.1314 - val_accuracy: 0.9850 - val_loss: 0.1485 - learning_rate: 5.0000e-04
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9896 - loss: 0.1246 - val_accuracy: 0.9853 - val_loss: 0.1458 - learning_rate: 5.0000e-04
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.9893 - loss: 0.1221 - val_accuracy: 0.9853 - val_loss: 0.1457 - learning_rate: 5.0000e-04
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.9893 - loss: 0.1200 - val_accuracy: 0.9838 - val_loss: 0.1437 - learning_rate: 5.0000e-04
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9910 - loss: 0.1149 - val_accuracy: 0.9838 - val_loss: 0.1488 - learning_rate: 5.0000e-04
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 44s 55ms/step - accuracy: 0.9904 - loss: 0.1147 - val_accuracy: 0.9862 - val_loss: 0.1358 - learning_rate: 5.0000e-04
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 39s 51ms/step - accuracy: 0.9885 - loss: 0.1165 - val_accuracy: 0.9850 - val_loss: 0.1361 - learning_rate: 5.0000e-04
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9912 - loss: 0.1112
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 48ms/step - accuracy: 0.9912 - loss: 0.1112 - val_accuracy: 0.9847 - val_loss: 0.1387 - learning_rate: 5.0000e-04
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 22s 50ms/step - accuracy: 0.9928 - loss: 0.1022 - val_accuracy: 0.9878 - val_loss: 0.1253 - learning_rate: 2.5000e-04
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9945 - loss: 0.0914 - val_accuracy: 0.9875 - val_loss: 0.1211 - learning_rate: 2.5000e-04
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9948 - loss: 0.0872 - val_accuracy: 0.9848 - val_loss: 0.1221 - learning_rate: 2.5000e-04
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9947 - loss: 0.0839
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9947 - loss: 0.0839 - val_accuracy: 0.9857 - val_loss: 0.1229 - learning_rate: 2.5000e-04
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 51ms/step - accuracy: 0.9964 - loss: 0.0771 - val_accuracy: 0.9893 - val_loss: 0.1089 - learning_rate: 1.2500e-04
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9973 - loss: 0.0718 - val_accuracy: 0.9887 - val_loss: 0.1063 - learning_rate: 1.2500e-04
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9969 - loss: 0.0705 - val_accuracy: 0.9893 - val_loss: 0.1046 - learning_rate: 1.2500e-04
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9970 - loss: 0.0677 - val_accuracy: 0.9895 - val_loss: 0.1008 - learning_rate: 1.2500e-04
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9968 - loss: 0.0658 - val_accuracy: 0.9905 - val_loss: 0.0994 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 30.

# %%
test_labels_cat = to_categorical(test_labels, num_classes=10)
test_loss, test_acc = model.evaluate(test_images, test_labels_cat)
print(f"\n✅ Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9840 - loss: 0.1121
#
# ✅ Test Accuracy: 0.9863

# %%
# Plotting training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
predictions = model.predict(test_images)
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(test_images[i].reshape(28, 28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = test_labels[i]
    color = 'green' if pred_label == true_label else 'red'
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
